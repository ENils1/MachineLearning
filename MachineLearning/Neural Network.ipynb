# %%
from sklearn.neural_network import MLPRegressor
from utility import start
from utility import train

X_train, X_test, y_train, y_test, df = start("encoded_data_04_13.csv")

# %%
model = MLPRegressor(hidden_layer_sizes=(100,),  # Example hidden layer size
                     activation='relu',  # Activation function (Rectified Linear Unit)
                     solver='adam',  # Optimizer algorithm
                     max_iter=1000,  # Maximum number of iterations
                     random_state=42)  # Random seed for reproducibility
y_pred, y_pred_original, y_test_original = train(model, X_train, X_test, y_train, y_test)
# Out:
# c:\Users\mg\Documents\GitHub\MachineLearning\MachineLearning\utility.py:21: RuntimeWarning: overflow encountered in power
#   y_train_original = np.power(10, y_train_pred)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 6
#       1 model = MLPRegressor(hidden_layer_sizes=(100,),  # Example hidden layer size
#       2                      activation='relu',  # Activation function (Rectified Linear Unit)
#       3                      solver='adam',  # Optimizer algorithm
#       4                      max_iter=1000,  # Maximum number of iterations
#       5                      random_state=42)  # Random seed for reproducibility
# ----> 6 y_pred, y_pred_original, y_test_original = train(model, X_train, X_test, y_train, y_test)
#
# File c:\Users\mg\Documents\GitHub\MachineLearning\MachineLearning\utility.py:24, in train(model, X_train, X_test, y_train, y_test)
#      21 y_train_original = np.power(10, y_train_pred)
#      23 # Calculate MAE and MAPE on the training data
# ---> 24 mae_train = mean_absolute_error(np.power(10, y_train), y_train_original)
#      25 mape_train = np.mean(np.abs((np.power(10, y_train) - y_train_original) / np.power(10, y_train))) * 100
#      27 print("Training Set Scores:")
#
# File c:\Users\mg\Documents\GitHub\MachineLearning\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\Users\mg\Documents\GitHub\MachineLearning\.venv\Lib\site-packages\sklearn\metrics\_regression.py:207, in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
#     143 @validate_params(
#     144     {
#     145         "y_true": ["array-like"],
#    (...)
#     153     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average"
#     154 ):
#     155     """Mean absolute error regression loss.
#     156
#     157     Read more in the :ref:`User Guide <mean_absolute_error>`.
#    (...)
#     205     0.85...
#     206     """
# --> 207     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     208         y_true, y_pred, multioutput
#     209     )
#     210     check_consistent_length(y_true, y_pred, sample_weight)
#     211     output_errors = np.average(np.abs(y_pred - y_true), weights=sample_weight, axis=0)
#
# File c:\Users\mg\Documents\GitHub\MachineLearning\.venv\Lib\site-packages\sklearn\metrics\_regression.py:104, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#     102 check_consistent_length(y_true, y_pred)
#     103 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
# --> 104 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     106 if y_true.ndim == 1:
#     107     y_true = y_true.reshape((-1, 1))
#
# File c:\Users\mg\Documents\GitHub\MachineLearning\.venv\Lib\site-packages\sklearn\utils\validation.py:1049, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1043     raise ValueError(
#    1044         "Found array with dim %d. %s expected <= 2."
#    1045         % (array.ndim, estimator_name)
#    1046     )
#    1048 if force_all_finite:
# -> 1049     _assert_all_finite(
#    1050         array,
#    1051         input_name=input_name,
#    1052         estimator_name=estimator_name,
#    1053         allow_nan=force_all_finite == "allow-nan",
#    1054     )
#    1056 if copy:
#    1057     if _is_numpy_namespace(xp):
#    1058         # only make a copy if `array` and `array_orig` may share memory`
#
# File c:\Users\mg\Documents\GitHub\MachineLearning\.venv\Lib\site-packages\sklearn\utils\validation.py:126, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     123 if first_pass_isfinite:
#     124     return
# --> 126 _assert_all_finite_element_wise(
#     127     X,
#     128     xp=xp,
#     129     allow_nan=allow_nan,
#     130     msg_dtype=msg_dtype,
#     131     estimator_name=estimator_name,
#     132     input_name=input_name,
#     133 )
#
# File c:\Users\mg\Documents\GitHub\MachineLearning\.venv\Lib\site-packages\sklearn\utils\validation.py:175, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     158 if estimator_name and input_name == "X" and has_nan_error:
#     159     # Improve the error message on how to handle missing values in
#     160     # scikit-learn.
#     161     msg_err += (
#     162         f"\n{estimator_name} does not accept missing values"
#     163         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     173         "#estimators-that-handle-nan-values"
#     174     )
# --> 175 raise ValueError(msg_err)
#
# ValueError: Input contains infinity or a value too large for dtype('float64').
